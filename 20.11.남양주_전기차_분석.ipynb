# %%
import pandas as pd
df01 = pd.read_csv('C:/Users/user/Desktop/workSpace/분석/표준분석모델/전기차_교육/정제데이터/남양주_데이터전처리.csv', encoding = 'utf8' ,engine='python')
df01.set_index('gid', inplace=True)
전체칼럼 = df01.columns.tolist()
print ("여기 칼럼명을 확인하신 후 점수계산에 필요한 칼럼명만 복사 하세요.\n", 전체칼럼)
# Out:
# 여기 칼럼명을 확인하신 후 점수계산에 필요한 칼럼명만 복사 하세요.
#  ['주차장', '건물1', '건물2', '건물3', '경제인구', '관공서', '교통량', '변압기', '전기차', '충전소', '경도', '위도']

# %%
# 가중치와 합계에 필요한 칼럼 추출
점수칼럼 =  ['주차장', '건물1', '건물2', '건물3', '경제인구', '관공서', '교통량', '변압기', '전기차', '충전소']
print("입력한 점수컬럼명은 다음과 같음\n", 점수칼럼)

가중치 = [1] * len(점수칼럼)
# Out:
# 입력한 점수컬럼명은 다음과 같음
#  ['주차장', '건물1', '건물2', '건물3', '경제인구', '관공서', '교통량', '변압기', '전기차', '충전소']

# %%
# 가중치 배정
가중치 = [1,1,2,3,1,3,1,1,2,-3]


# 수정 불필요
if (len(가중치) != len(점수칼럼)):
    print("입력한 가중치 갯수가 점수칼럼 갯수와 다르므로 확인후 다시 입력 바랍니다")
else:
    print("다음 줄을 실행 하세요")
# Out:
# 다음 줄을 실행 하세요

# %%
df = pd.read_csv('C:/Users/user/Desktop/workSpace/분석/표준분석모델/전기차_교육/정제데이터/남양주_데이터전처리.csv', encoding = 'utf8' ,engine='python')
df.set_index('gid', inplace=True)

################## QGIS에서 작업한 전처리 결과 CSV 읽기 ####################################################
pre_process_set = pd.read_csv('C:/Users/user/Desktop/workSpace/분석/표준분석모델/전기차_교육/정제데이터/남양주_데이터전처리.csv', encoding = 'utf8' ,engine='python')
pre_process_set = pre_process_set.sort_values(by='gid')

# Null 이 있을 수 있는 칼럼은 Null을 0로 변경
pre_process_set.fillna(0, inplace=True)
##################  QGIS에서 작업한 전처리 결과 CSV 읽기 끝###################################################

# 점수칼럼 정규화
norm = pre_process_set.copy()
norm.fillna(0, inplace=True)
norm.set_index('gid', inplace=True)    # gid를 인덱스 설정

norm[점수칼럼] = (norm.loc[:,점수칼럼] - norm.loc[:,점수칼럼].mean())/norm.loc[:,점수칼럼].std()
norm.reset_index(inplace=True)    # 설정한 인덱스를 해제
################## 정규화 끝################################################################################


# 총점 계산
df = norm.copy()

for i in range(0, len(점수칼럼)):
    name = 점수칼럼[i]
    df[name] = df[name] * 가중치[i] 

df.set_index(['gid','경도','위도'], inplace=True)

df['sum'] = df.sum(1)
df.reset_index(inplace=True)

# 등수 계산 
df['순위'] = df['sum'].rank(method='dense', ascending=False).astype(int)

final = df.sort_values(by='순위')
final.reset_index(drop=True, inplace=True)

# 상위 20개만 학인
display("결과", final.head(20))

# 최종 결과 CSV 파일쓰기
final.to_csv('결과_총점.csv', index=False, sep=',', encoding='cp949')
# 13   -0.176376   6.705699  45.419486  3.754280 -0.06831   7.801961  0.194845
# 14   -0.176376   6.399030  30.148001  2.499852 -0.06831  15.875258  0.194845
# 15   -0.176376   7.046443  -0.394969  3.921537 -0.06831  15.875258  0.194845
# 16   -0.176376   7.803651  14.876516  1.412682 -0.06831  23.948555  0.194845
# 17   -0.176376   9.030328  14.876516  0.994539 -0.06831  23.948555  0.194845
# 18   40.534462   6.141579  -0.394969  4.005166 -0.06831   7.801961  0.194845
# 19   -0.176376   7.985381  14.876516  6.012250 -0.06831  32.021852  0.194845
#
#            sum  순위
# 0   154.103701   1
# 1   143.511620   2
# 2   131.839446   3
# 3   102.253485   4
# 4    95.963411   5
# 5    83.270078   6
# 6    79.355206   7
# 7    76.065276   8
# 8    73.168467   9
# 9    73.107729  10
# 10   72.617903  11
# 11   71.785225  12
# 12   70.166789  13
# 13   68.926205  14
# 14   68.830042  15
# 15   68.677942  16
# 16   68.317658  17
# 17   67.774442  18
# 18   66.473121  19
# 19   65.049292  20

# %%
df = pd.read_csv('C:/Users/user/Desktop/workSpace/분석/표준분석모델/전기차_교육/정제데이터/남양주_데이터전처리.csv', encoding = 'utf8' ,engine='python')
df.set_index('gid', inplace=True)

################## QGIS에서 작업한 전처리 결과 CSV 읽기 ####################################################
pre_process_set = pd.read_csv('C:/Users/user/Desktop/workSpace/분석/표준분석모델/전기차_교육/정제데이터/남양주_데이터전처리.csv', encoding = 'utf8' ,engine='python')
pre_process_set = pre_process_set.sort_values(by='gid')

# Null 이 있을 수 있는 칼럼은 Null을 0로 변경
pre_process_set.fillna(0, inplace=True)
##################  QGIS에서 작업한 전처리 결과 CSV 읽기 끝###################################################


norm = pre_process_set.copy()
norm.fillna(0, inplace=True)
norm.set_index('gid', inplace=True)    # gid를 인덱스 설정

norm[점수칼럼] = (norm.loc[:,점수칼럼] - norm.loc[:,점수칼럼].mean())/norm.loc[:,점수칼럼].std()
norm.reset_index(inplace=True)    # 설정한 인덱스를 해제

############ 정규화 완료 ############

df1000 = norm.copy()

for i in range(0, len(점수칼럼)):
    name = 점수칼럼[i]
    df1000[name] = df1000[name] * 가중치[i] 

df1000.set_index(['gid','경도','위도'], inplace=True)

df1000['sum'] = df1000.sum(1)
df1000.reset_index(inplace=True)

# %%
df1000.head()
# Out:
#           gid          경도         위도       주차장       건물1      건물2       건물3  \
# 0  다사62bb66ba  127.078871  37.698435 -0.074092 -0.466883 -0.38429 -0.176376
# 1  다사63aa66aa  127.081732  37.693938 -0.074092 -0.466883 -0.38429 -0.176376
# 2  다사63aa66ab  127.081719  37.696192 -0.074092 -0.466883 -0.38429 -0.176376
# 3  다사63aa66ba  127.081706  37.698445 -0.074092 -0.466883 -0.38429 -0.176376
# 4  다사63aa66bb  127.081694  37.700698 -0.074092 -0.332167 -0.38429 -0.176376
#
#        경제인구       관공서       교통량      변압기       전기차       충전소       sum
# 0 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713
# 1 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713
# 2 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713
# 3 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713
# 4 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.338996

# %%
# 등수 계산 
#df1000['순위'] = df1000['sum'].rank(method='dense', ascending=False).astype(int)

df1000['순위'] = df1000['sum'].rank(method='min', ascending = False).astype(int)

# final = df1000.sort_values(by='순위')
# final.reset_index(drop=True, inplace=True)

# %%
display("결과", df1000.head(20))
# Out:
# '결과'
#            gid          경도         위도       주차장       건물1      건물2       건물3  \
# 0   다사62bb66ba  127.078871  37.698435 -0.074092 -0.466883 -0.38429 -0.176376
# 1   다사63aa66aa  127.081732  37.693938 -0.074092 -0.466883 -0.38429 -0.176376
# 2   다사63aa66ab  127.081719  37.696192 -0.074092 -0.466883 -0.38429 -0.176376
# 3   다사63aa66ba  127.081706  37.698445 -0.074092 -0.466883 -0.38429 -0.176376
# 4   다사63aa66bb  127.081694  37.700698 -0.074092 -0.332167 -0.38429 -0.176376
# 5   다사63ab65ba  127.084593  37.689442 -0.074092 -0.466883 -0.38429 -0.176376
# 6   다사63ab65bb  127.084580  37.691695 -0.074092 -0.466883 -0.38429 -0.176376
# 7   다사63ab66aa  127.084568  37.693948 -0.074092 -0.466883 -0.38429 -0.176376
# 8   다사63ab66ab  127.084555  37.696202 -0.074092 -0.466883 -0.38429 -0.176376
# 9   다사63ab66ba  127.084542  37.698455 -0.074092 -0.466883 -0.38429 -0.176376
# 10  다사63ab66bb  127.084530  37.700708 -0.074092 -0.466883 -0.38429 -0.176376
# 11  다사63ab67aa  127.084517  37.702961 -0.074092 -0.466883 -0.38429 -0.176376
# 12  다사63ba65ba  127.087428  37.689452 -0.074092 -0.466883 -0.38429 -0.176376
# 13  다사63ba65bb  127.087416  37.691705 -0.074092 -0.466883 -0.38429 -0.176376
# 14  다사63ba66aa  127.087403  37.693958 -0.074092 -0.466883 -0.38429 -0.176376
# 15  다사63ba66ab  127.087391  37.696212 -0.074092 -0.466883 -0.38429 -0.176376
# 16  다사63ba66ba  127.087378  37.698465 -0.074092 -0.466883 -0.38429 -0.176376
# 17  다사63ba66bb  127.087366  37.700718 -0.074092 -0.466883 -0.38429 -0.176376
# 18  다사63ba67aa  127.087353  37.702971 -0.074092 -0.466883 -0.38429 -0.176376
# 19  다사63bb62aa  127.090437  37.657915 -0.074092 -0.466883 -0.38429 -0.176376
#
#         경제인구       관공서       교통량      변압기       전기차       충전소       sum    순위
# 0  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 1  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 2  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 3  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 4  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.338996  3778
# 5  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 6  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 7  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 8  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 9  -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 10 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 11 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 12 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 13 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 14 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 15 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 16 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 17 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 18 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
# 19 -0.237898 -0.394969 -0.594403 -0.06831 -0.271336  0.194845 -2.473713  4085
